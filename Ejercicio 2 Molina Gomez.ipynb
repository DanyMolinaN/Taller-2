# %% [markdown]
# <div style="text-align: center;">
#
# ## Escuela Politécnica Nacional
#
# </div>
#
# **Integrantes:**
#
#  Kevin Gómez
#
#  Dany Molina Israel
#
# <div style="text-align: center;">
#
# ## Taller 2 - Ejericio 2
#
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML  # Solo necesario si usas Jupyter Notebook

# Definir la función y su derivada
def f(x):
    return ((x + 3)/2)**2 - 2

def df(x):
    return (x + 3)/2

# Método de Newton (modificado para guardar los pasos)
def newton_method_steps(f, df, x0, tol=1e-6, max_iter=100):
    steps = [x0]  # Guardar todas las aproximaciones
    for _ in range(max_iter):
        x1 = x0 - f(x0)/df(x0)
        steps.append(x1)
        if abs(x1 - x0) < tol:
            break
        x0 = x1
    return steps

# Puntos iniciales para las dos raíces
x0_1 = 0
x0_2 = -6

# Obtener los pasos para cada raíz
steps_x1 = newton_method_steps(f, df, x0_1)
steps_x2 = newton_method_steps(f, df, x0_2)

# Configurar la figura para la animación
fig, ax = plt.subplots(figsize=(10, 8))

# Graficar la hipérbola
x_vals = np.linspace(-10, 4, 400)
y_pos = np.sqrt((x_vals + 3)**2 - 4)
y_neg = -np.sqrt((x_vals + 3)**2 - 4)
valid = (x_vals + 3)**2 - 4 >= 0
x_valid = x_vals[valid]

ax.plot(x_valid, y_pos[valid], 'b-', label='Hipérbola (parte superior)')
ax.plot(x_valid, y_neg[valid], 'b-', label='Hipérbola (parte inferior)')
ax.axhline(y=-2, color='r', linestyle='--', label='y = -2')

# Líneas y puntos para la animación
(line1,) = ax.plot([], [], 'go-', lw=2, label='Iteraciones (x1)')
(line2,) = ax.plot([], [], 'mo-', lw=2, label='Iteraciones (x2)')
(point1,) = ax.plot([], [], 'ro', markersize=8)
(point2,) = ax.plot([], [], 'ro', markersize=8)

# Configuración de los ejes y leyenda
ax.set_xlim(-10, 6)
ax.set_ylim(-8, 6)
ax.axhline(y=0, color='k', linestyle='-', linewidth=0.5)
ax.axvline(x=0, color='k', linestyle='-', linewidth=0.5)
ax.set_title('Animación del Método de Newton')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.grid(True, linestyle='--', alpha=0.5)
ax.legend()

# Función de inicialización para la animación
def init():
    line1.set_data([], [])
    line2.set_data([], [])
    point1.set_data([], [])
    point2.set_data([], [])
    return line1, line2, point1, point2

# Función de actualización para cada frame de la animación
def update(frame):
    # Actualizar las líneas de iteración para x1 y x2
    if frame < len(steps_x1):
        x1_current = steps_x1[frame]
        line1.set_data([x1_current, x1_current], [0, -2])
    if frame < len(steps_x2):
        x2_current = steps_x2[frame]
        line2.set_data([x2_current, x2_current], [0, -2])
    
    # Actualizar los puntos de intersección finales
    if frame == max(len(steps_x1), len(steps_x2)) - 1:
        point1.set_data([steps_x1[-1]], [-2])
        point2.set_data([steps_x2[-1]], [-2])
    
    return line1, line2, point1, point2

# Crear la animación
animation = FuncAnimation(
    fig,
    update,
    frames=max(len(steps_x1), len(steps_x2)),
    init_func=init,
    blit=True,
    interval=1000,  # 1 segundo entre frames
    repeat=False
)

# Mostrar la animación en una ventana emergente (VS Code o Jupyter)
plt.close()  # Evita que se muestre la figura estática primero
animation.save('newton_animation.gif', writer='pillow', fps=1)  # Guardar como GIF
print("¡Animación guardada como 'newton_animation.gif'!")

# Para visualizar en VS Code (requiere tener instalado el soporte para animaciones)
plt.show()
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_10296\2629480694.py:37: RuntimeWarning: invalid value encountered in sqrt
#   y_pos = np.sqrt((x_vals + 3)**2 - 4)
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_10296\2629480694.py:38: RuntimeWarning: invalid value encountered in sqrt
#   y_neg = -np.sqrt((x_vals + 3)**2 - 4)
# ¡Animación guardada como 'newton_animation.gif'!
